# %%
#write a function that takes the age prints whether the person is adult or not
def adult():
  if age>=18:
    return ("the person is adult  ")
  else:
    return ("the person is not adult")
age=int(input("enter the age"))
print(adult())
# Out:
# enter the age58
# the person is adult
